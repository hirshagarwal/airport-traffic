# %% [markdown]
# # OpenSky Arrivals Helper
# This notebook demonstrates a helper that pulls today's arrivals for Boston Logan International Airport (BOS/KBOS) via the OpenSky API.

# %%
from datetime import datetime, timedelta, timezone
from pathlib import Path
from typing import Any, List, Optional
import os
import requests

import pandas as pd
from dotenv import load_dotenv

# Locate and load the nearest .env file (walk upwards from the notebook directory).
def _load_env() -> None:
    search_root = Path.cwd().resolve()
    for candidate in [search_root] + list(search_root.parents):
        env_path = candidate / '.env'
        if env_path.exists():
            print(os.environ.get('OPENSKY_USERNAME'))
            load_dotenv(env_path, override=True)
            return
    raise FileNotFoundError('No .env file found in notebook directory hierarchy.')


_load_env()
username = os.environ.get('OPENSKY_USERNAME')
password = os.environ.get('OPENSKY_PASSWORD')
# Out:
# None

# %%
AUTH_URL = "https://auth.opensky-network.org/auth/realms/opensky-network/protocol/openid-connect/token"

def get_auth_token(
    *,
    client_id: Optional[str] = None,
    client_secret: Optional[str] = None,
    timeout: float = 30.0,
) -> str:
    """Exchange OpenSky credentials for an access token using the client-credentials flow."""
    resolved_client_id = (client_id or os.environ.get("OPENSKY_CLIENT_ID") or username or "").strip()
    resolved_client_secret = (client_secret or os.environ.get("OPENSKY_CLIENT_SECRET") or password or "").strip()
    if not resolved_client_id or not resolved_client_secret:
        raise ValueError("Both client_id and client_secret are required to fetch an auth token.")

    payload = {
        "grant_type": "client_credentials",
        "client_id": resolved_client_id,
        "client_secret": resolved_client_secret,
    }

    response = requests.post(
        AUTH_URL,
        headers={"Content-Type": "application/x-www-form-urlencoded"},
        data=payload,
        timeout=timeout,
    )
    response.raise_for_status()
    token_response = response.json()
    try:
        return token_response["access_token"]
    except KeyError as exc:
        raise ValueError("OpenSky auth response did not include an access_token.") from exc

# %%
token = get_auth_token()

# %%
OPEN_SKY_BASE_URL = "https://opensky-network.org/api"

def _ensure_timestamp(value: any) -> int:
    """Convert assorted timestamp inputs into the Unix epoch seconds OpenSky expects."""
    if isinstance(value, (int, float)):
        return int(value)
    converter = globals().get("datetime_to_unix")
    if converter is not None:
        return converter(value)  # Defer to the shared helper when available.
    if isinstance(value, datetime):
        dt = value
    elif isinstance(value, str):
        stripped = value.strip()
        if not stripped:
            raise ValueError("Timestamp string is empty.")
        normalized = stripped[:-1] + "+00:00" if stripped.endswith("Z") else stripped
        try:
            dt = datetime.fromisoformat(normalized)
        except ValueError as exc:
            raise ValueError(f"Unsupported timestamp string: {value}") from exc
    else:
        raise TypeError(f"Unsupported timestamp type: {type(value)!r}")
    if dt.tzinfo is None:
        dt = dt.replace(tzinfo=timezone.utc)
    else:
        dt = dt.astimezone(timezone.utc)
    return int(dt.timestamp())

def get_departures(
    airport: str,
    begin: any,
    end: any,
    *,
    token_override: Optional[str] = None,
    session: Optional[requests.Session] = None,
    timeout: float = 30.0,
) -> List[dict]:
    """Fetch departure flights for an airport via the OpenSky REST endpoint."""
    if not airport:
        raise ValueError("airport is required")
    begin_ts = _ensure_timestamp(begin)
    end_ts = _ensure_timestamp(end)
    if end_ts <= begin_ts:
        raise ValueError("end must be after begin")

    auth_token = (token_override or token or "").strip()
    if not auth_token:
        raise ValueError("An OpenSky auth token is required to call the REST endpoint.")
    headers = {"Authorization": f"Bearer {auth_token}"}
    params = {
        "airport": airport.upper(),
        "begin": begin_ts,
        "end": end_ts,
    }

    request_session = session or requests.Session()
    try:
        response = request_session.get(
            f"{OPEN_SKY_BASE_URL}/flights/departure",
            params=params,
            headers=headers,
            timeout=timeout,
        )
        response.raise_for_status()
        payload = response.json()
    finally:
        if session is None:
            request_session.close()

    if not isinstance(payload, list):
        raise ValueError("Unexpected response from OpenSky departures endpoint.")

    return payload

# %%
def datetime_to_unix(String: datetime) -> int:
    """Convert a datetime or ISO formatted string into a Unix timestamp."""
    if isinstance(String, datetime):
        dt = String
    elif isinstance(String, str):
        value = String.strip()
        if not value:
            raise ValueError("datetime string is empty")
        normalized = value[:-1] + "+00:00" if value.endswith("Z") else value
        try:
            dt = datetime.fromisoformat(normalized)
        except ValueError as exc:
            try:
                dt = datetime.strptime(value, "%Y-%m-%d %H:%M:%S")
            except ValueError as fallback_exc:
                raise ValueError(f"Unsupported datetime string: {String}") from fallback_exc
    else:
        raise TypeError("datetime_to_unix expects a datetime or str instance")
    if dt.tzinfo is None:
        dt = dt.replace(tzinfo=timezone.utc)
    else:
        dt = dt.astimezone(timezone.utc)
    return int(dt.timestamp())

# %%
start = datetime_to_unix("2025-08-17 13:00:00")
end = datetime_to_unix("2025-08-17 15:00:00")
# data = api.get_flights_from_interval(1517227200, 1517230800)
s = api.get_states()
print(s)  # Print the retrieved states for debugging purposes.
# Out:
# None

# %%
start = datetime_to_unix("2025-08-17 13:00:00")
end = datetime_to_unix("2025-08-17 15:00:00")
get_departures("EDDF", 1517227200, 1517230800)
# Out:
# [{'icao24': '3c4ad0',
#   'firstSeen': 1517230790,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517238306,
#   'estArrivalAirport': None,
#   'callsign': 'DLH630  ',
#   'estDepartureAirportHorizDistance': 4319,
#   'estDepartureAirportVertDistance': 65,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c5469',
#   'firstSeen': 1517230716,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517233481,
#   'estArrivalAirport': 'LSGG',
#   'callsign': 'DLH5LA  ',
#   'estDepartureAirportHorizDistance': 4362,
#   'estDepartureAirportVertDistance': 103,
#   'estArrivalAirportHorizDistance': 1803,
#   'estArrivalAirportVertDistance': 163,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '4baa03',
#   'firstSeen': 1517230625,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517238702,
#   'estArrivalAirport': None,
#   'callsign': 'THY9AD  ',
#   'estDepartureAirportHorizDistance': 3764,
#   'estDepartureAirportVertDistance': 80,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '4951d0',
#   'firstSeen': 1517230550,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517240237,
#   'estArrivalAirport': 'LPCS',
#   'callsign': 'TAP583  ',
#   'estDepartureAirportHorizDistance': 3808,
#   'estDepartureAirportVertDistance': 80,
#   'estArrivalAirportHorizDistance': 14016,
#   'estArrivalAirportVertDistance': 708,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 3},
#  {'icao24': '780b7d',
#   'firstSeen': 1517230493,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517295442,
#   'estArrivalAirport': None,
#   'callsign': 'CES220  ',
#   'estDepartureAirportHorizDistance': 1464,
#   'estDepartureAirportVertDistance': 11,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c66aa',
#   'firstSeen': 1517230395,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517237893,
#   'estArrivalAirport': None,
#   'callsign': 'DLH1436 ',
#   'estDepartureAirportHorizDistance': 1190,
#   'estDepartureAirportVertDistance': 34,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c66a9',
#   'firstSeen': 1517230317,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517241232,
#   'estArrivalAirport': None,
#   'callsign': 'DLH692  ',
#   'estDepartureAirportHorizDistance': 3943,
#   'estDepartureAirportVertDistance': 27,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c4ad7',
#   'firstSeen': 1517230176,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517265128,
#   'estArrivalAirport': 'KDEN',
#   'callsign': 'DLH446  ',
#   'estDepartureAirportHorizDistance': 1425,
#   'estDepartureAirportVertDistance': 103,
#   'estArrivalAirportHorizDistance': 2948,
#   'estArrivalAirportVertDistance': 43,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '3c65a5',
#   'firstSeen': 1517230169,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517302940,
#   'estArrivalAirport': 'EDDF',
#   'callsign': 'DLH761  ',
#   'estDepartureAirportHorizDistance': 4685,
#   'estDepartureAirportVertDistance': 72,
#   'estArrivalAirportHorizDistance': 2005,
#   'estArrivalAirportVertDistance': 110,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 3},
#  {'icao24': '3c648c',
#   'firstSeen': 1517230167,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517238643,
#   'estArrivalAirport': None,
#   'callsign': 'DLH580  ',
#   'estDepartureAirportHorizDistance': 1845,
#   'estDepartureAirportVertDistance': 126,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c70c3',
#   'firstSeen': 1517230068,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517236678,
#   'estArrivalAirport': None,
#   'callsign': 'GEC8410 ',
#   'estDepartureAirportHorizDistance': 1907,
#   'estDepartureAirportVertDistance': 49,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c644a',
#   'firstSeen': 1517229990,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517232089,
#   'estArrivalAirport': 'EDDV',
#   'callsign': 'DLH052  ',
#   'estDepartureAirportHorizDistance': 816,
#   'estDepartureAirportVertDistance': 19,
#   'estArrivalAirportHorizDistance': 1739,
#   'estArrivalAirportVertDistance': 55,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '3c64f3',
#   'firstSeen': 1517229981,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517318413,
#   'estArrivalAirport': 'EDDF',
#   'callsign': 'DLH542  ',
#   'estDepartureAirportHorizDistance': 4690,
#   'estDepartureAirportVertDistance': 57,
#   'estArrivalAirportHorizDistance': 2461,
#   'estArrivalAirportVertDistance': 80,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 3},
#  {'icao24': '3c6593',
#   'firstSeen': 1517229860,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517232089,
#   'estArrivalAirport': 'EBBR',
#   'callsign': 'DLH9MM  ',
#   'estDepartureAirportHorizDistance': 3657,
#   'estDepartureAirportVertDistance': 88,
#   'estArrivalAirportHorizDistance': 3061,
#   'estArrivalAirportVertDistance': 86,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 1},
#  {'icao24': '3c4b26',
#   'firstSeen': 1517229760,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517261535,
#   'estArrivalAirport': 'KEWR',
#   'callsign': 'DLH402  ',
#   'estDepartureAirportHorizDistance': 4693,
#   'estDepartureAirportVertDistance': 110,
#   'estArrivalAirportHorizDistance': 855,
#   'estArrivalAirportVertDistance': 51,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 6},
#  {'icao24': '4cc275',
#   'firstSeen': 1517229634,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517242017,
#   'estArrivalAirport': 'BIKF',
#   'callsign': 'ICE521  ',
#   'estDepartureAirportHorizDistance': 1093,
#   'estDepartureAirportVertDistance': 57,
#   'estArrivalAirportHorizDistance': 510,
#   'estArrivalAirportVertDistance': 62,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c6626',
#   'firstSeen': 1517229453,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517231817,
#   'estArrivalAirport': 'EDDM',
#   'callsign': 'DLH3XN  ',
#   'estDepartureAirportHorizDistance': 3312,
#   'estDepartureAirportVertDistance': 126,
#   'estArrivalAirportHorizDistance': 1050,
#   'estArrivalAirportVertDistance': 125,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 3},
#  {'icao24': '3c5463',
#   'firstSeen': 1517229423,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517233199,
#   'estArrivalAirport': 'EPPO',
#   'callsign': 'DLH6RV  ',
#   'estDepartureAirportHorizDistance': 3844,
#   'estDepartureAirportVertDistance': 95,
#   'estArrivalAirportHorizDistance': 685,
#   'estArrivalAirportVertDistance': 10,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 1},
#  {'icao24': '3c6566',
#   'firstSeen': 1517229409,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517255445,
#   'estArrivalAirport': None,
#   'callsign': 'DLH646  ',
#   'estDepartureAirportHorizDistance': 1381,
#   'estDepartureAirportVertDistance': 49,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c667a',
#   'firstSeen': 1517229342,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517232179,
#   'estArrivalAirport': 'EDDT',
#   'callsign': 'DLH8HU  ',
#   'estDepartureAirportHorizDistance': 1366,
#   'estDepartureAirportVertDistance': 103,
#   'estArrivalAirportHorizDistance': 1642,
#   'estArrivalAirportVertDistance': 14,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '3c6588',
#   'firstSeen': 1517229323,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517231635,
#   'estArrivalAirport': 'EDDC',
#   'callsign': 'DLH3MC  ',
#   'estDepartureAirportHorizDistance': 3468,
#   'estDepartureAirportVertDistance': 80,
#   'estArrivalAirportHorizDistance': 5031,
#   'estArrivalAirportVertDistance': 128,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '3c66ae',
#   'firstSeen': 1517229249,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517235258,
#   'estArrivalAirport': 'ESSA',
#   'callsign': 'DLH2XA  ',
#   'estDepartureAirportHorizDistance': 1398,
#   'estDepartureAirportVertDistance': 95,
#   'estArrivalAirportHorizDistance': 7285,
#   'estArrivalAirportVertDistance': 369,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 3},
#  {'icao24': '3c66a2',
#   'firstSeen': 1517229233,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517240146,
#   'estArrivalAirport': None,
#   'callsign': 'DLH1306 ',
#   'estDepartureAirportHorizDistance': 4027,
#   'estDepartureAirportVertDistance': 11,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c6590',
#   'firstSeen': 1517229150,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517231522,
#   'estArrivalAirport': 'EDWM',
#   'callsign': 'DLH2EU  ',
#   'estDepartureAirportHorizDistance': 971,
#   'estDepartureAirportVertDistance': 11,
#   'estArrivalAirportHorizDistance': 11826,
#   'estArrivalAirportVertDistance': 774,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 4},
#  {'icao24': '3c6571',
#   'firstSeen': 1517229094,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517237038,
#   'estArrivalAirport': None,
#   'callsign': 'DLH624  ',
#   'estDepartureAirportHorizDistance': 4125,
#   'estDepartureAirportVertDistance': 42,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c6655',
#   'firstSeen': 1517229007,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517230967,
#   'estArrivalAirport': 'EDDL',
#   'callsign': 'DLH076  ',
#   'estDepartureAirportHorizDistance': 1038,
#   'estDepartureAirportVertDistance': 88,
#   'estArrivalAirportHorizDistance': 2115,
#   'estArrivalAirportVertDistance': 44,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '3c66ac',
#   'firstSeen': 1517228857,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517236078,
#   'estArrivalAirport': 'EFHK',
#   'callsign': 'DLH3PP  ',
#   'estDepartureAirportHorizDistance': 1441,
#   'estDepartureAirportVertDistance': 88,
#   'estArrivalAirportHorizDistance': 3671,
#   'estArrivalAirportVertDistance': 105,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '3c6487',
#   'firstSeen': 1517228827,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517237334,
#   'estArrivalAirport': 'LTBX',
#   'callsign': 'DLH1298 ',
#   'estDepartureAirportHorizDistance': 3907,
#   'estDepartureAirportVertDistance': 95,
#   'estArrivalAirportHorizDistance': 24380,
#   'estArrivalAirportVertDistance': 2392,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c6598',
#   'firstSeen': 1517228681,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517230237,
#   'estArrivalAirport': 'EDDN',
#   'callsign': 'DLH8NL  ',
#   'estDepartureAirportHorizDistance': 3581,
#   'estDepartureAirportVertDistance': 80,
#   'estArrivalAirportHorizDistance': 576,
#   'estArrivalAirportVertDistance': 143,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c6621',
#   'firstSeen': 1517228596,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517234018,
#   'estArrivalAirport': 'EGCC',
#   'callsign': 'DLH938  ',
#   'estDepartureAirportHorizDistance': 958,
#   'estDepartureAirportVertDistance': 72,
#   'estArrivalAirportHorizDistance': 1706,
#   'estArrivalAirportVertDistance': 70,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '3c4b23',
#   'firstSeen': 1517228579,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517235952,
#   'estArrivalAirport': None,
#   'callsign': 'DLH754  ',
#   'estDepartureAirportHorizDistance': 4373,
#   'estDepartureAirportVertDistance': 72,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c64ed',
#   'firstSeen': 1517228461,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517261682,
#   'estArrivalAirport': 'KOQN',
#   'callsign': 'DLH426  ',
#   'estDepartureAirportHorizDistance': 1969,
#   'estDepartureAirportVertDistance': 80,
#   'estArrivalAirportHorizDistance': 14528,
#   'estArrivalAirportVertDistance': 1039,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 3},
#  {'icao24': '3c65c8',
#   'firstSeen': 1517228290,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517230990,
#   'estArrivalAirport': 'EDDH',
#   'callsign': 'DLH9XY  ',
#   'estDepartureAirportHorizDistance': 1078,
#   'estDepartureAirportVertDistance': 95,
#   'estArrivalAirportHorizDistance': 1597,
#   'estArrivalAirportVertDistance': 29,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '3c65c7',
#   'firstSeen': 1517228280,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517231639,
#   'estArrivalAirport': 'LIPZ',
#   'callsign': 'DLH7MJ  ',
#   'estDepartureAirportHorizDistance': 4050,
#   'estDepartureAirportVertDistance': 27,
#   'estArrivalAirportHorizDistance': 3157,
#   'estArrivalAirportVertDistance': 47,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 3},
#  {'icao24': '3c4b2b',
#   'firstSeen': 1517228057,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517260463,
#   'estArrivalAirport': 'KIAD',
#   'callsign': 'DLH418  ',
#   'estDepartureAirportHorizDistance': 4215,
#   'estDepartureAirportVertDistance': 118,
#   'estArrivalAirportHorizDistance': 1603,
#   'estArrivalAirportVertDistance': 41,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '3c658b',
#   'firstSeen': 1517228042,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517230706,
#   'estArrivalAirport': 'LFXA',
#   'callsign': 'DLH71F  ',
#   'estDepartureAirportHorizDistance': 3187,
#   'estDepartureAirportVertDistance': 133,
#   'estArrivalAirportHorizDistance': 12230,
#   'estArrivalAirportVertDistance': 1890,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 1},
#  {'icao24': '3c6749',
#   'firstSeen': 1517227975,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517229354,
#   'estArrivalAirport': 'EDDS',
#   'callsign': 'DLH9KK  ',
#   'estDepartureAirportHorizDistance': 3872,
#   'estDepartureAirportVertDistance': 72,
#   'estArrivalAirportHorizDistance': 4,
#   'estArrivalAirportVertDistance': 152,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 1},
#  {'icao24': '3c5465',
#   'firstSeen': 1517227902,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517231402,
#   'estArrivalAirport': 'LDZA',
#   'callsign': 'DLH4EN  ',
#   'estDepartureAirportHorizDistance': 3785,
#   'estDepartureAirportVertDistance': 80,
#   'estArrivalAirportHorizDistance': 11324,
#   'estArrivalAirportVertDistance': 395,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': 'a1f1a0',
#   'firstSeen': 1517227818,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517260749,
#   'estArrivalAirport': 'KORD',
#   'callsign': 'UAL906  ',
#   'estDepartureAirportHorizDistance': 1309,
#   'estDepartureAirportVertDistance': 95,
#   'estArrivalAirportHorizDistance': 3320,
#   'estArrivalAirportVertDistance': 14,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 3},
#  {'icao24': '3c658c',
#   'firstSeen': 1517227774,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517230964,
#   'estArrivalAirport': 'LIML',
#   'callsign': 'DLH1MH  ',
#   'estDepartureAirportHorizDistance': 3657,
#   'estDepartureAirportVertDistance': 65,
#   'estArrivalAirportHorizDistance': 4847,
#   'estArrivalAirportVertDistance': 60,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 1},
#  {'icao24': '3c6759',
#   'firstSeen': 1517227703,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517230797,
#   'estArrivalAirport': 'EHAM',
#   'callsign': 'DLH992  ',
#   'estDepartureAirportHorizDistance': 879,
#   'estDepartureAirportVertDistance': 95,
#   'estArrivalAirportHorizDistance': 2694,
#   'estArrivalAirportVertDistance': 42,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 1},
#  {'icao24': '4ca540',
#   'firstSeen': 1517227643,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517232928,
#   'estArrivalAirport': 'EGCC',
#   'callsign': 'RYR38RM ',
#   'estDepartureAirportHorizDistance': 1454,
#   'estDepartureAirportVertDistance': 10,
#   'estArrivalAirportHorizDistance': 3010,
#   'estArrivalAirportVertDistance': 5,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 2},
#  {'icao24': '3c4aa8',
#   'firstSeen': 1517227623,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517236570,
#   'estArrivalAirport': None,
#   'callsign': 'CFG744  ',
#   'estDepartureAirportHorizDistance': 4479,
#   'estDepartureAirportVertDistance': 56,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': 'a28dc8',
#   'firstSeen': 1517227542,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517268585,
#   'estArrivalAirport': 'KSFO',
#   'callsign': 'UAL59   ',
#   'estDepartureAirportHorizDistance': 1234,
#   'estDepartureAirportVertDistance': 65,
#   'estArrivalAirportHorizDistance': 2043,
#   'estArrivalAirportVertDistance': 34,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 5},
#  {'icao24': '3c6635',
#   'firstSeen': 1517227541,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517229910,
#   'estArrivalAirport': 'LKPR',
#   'callsign': 'DLH8FY  ',
#   'estDepartureAirportHorizDistance': 3712,
#   'estDepartureAirportVertDistance': 80,
#   'estArrivalAirportHorizDistance': 919,
#   'estArrivalAirportVertDistance': 105,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 4},
#  {'icao24': '3c648e',
#   'firstSeen': 1517227482,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517234564,
#   'estArrivalAirport': 'LEMD',
#   'callsign': 'DLH15T  ',
#   'estDepartureAirportHorizDistance': 3800,
#   'estDepartureAirportVertDistance': 88,
#   'estArrivalAirportHorizDistance': 1935,
#   'estArrivalAirportVertDistance': 197,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 3},
#  {'icao24': '780212',
#   'firstSeen': 1517227440,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517262987,
#   'estArrivalAirport': None,
#   'callsign': 'CPA288  ',
#   'estDepartureAirportHorizDistance': 1612,
#   'estDepartureAirportVertDistance': 95,
#   'estArrivalAirportHorizDistance': None,
#   'estArrivalAirportVertDistance': None,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '3c66af',
#   'firstSeen': 1517227336,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517233082,
#   'estArrivalAirport': 'ENGM',
#   'callsign': 'DLH4PH  ',
#   'estDepartureAirportHorizDistance': 1039,
#   'estDepartureAirportVertDistance': 80,
#   'estArrivalAirportHorizDistance': 10772,
#   'estArrivalAirportVertDistance': 623,
#   'departureAirportCandidatesCount': 1,
#   'arrivalAirportCandidatesCount': 1},
#  {'icao24': '440828',
#   'firstSeen': 1517227303,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517229529,
#   'estArrivalAirport': 'LOWS',
#   'callsign': 'AUA264  ',
#   'estDepartureAirportHorizDistance': 3736,
#   'estDepartureAirportVertDistance': 110,
#   'estArrivalAirportHorizDistance': 15781,
#   'estArrivalAirportVertDistance': 651,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 0},
#  {'icao24': '300558',
#   'firstSeen': 1517227241,
#   'estDepartureAirport': 'EDDF',
#   'lastSeen': 1517229915,
#   'estArrivalAirport': 'LIPO',
#   'callsign': 'DLH5RM  ',
#   'estDepartureAirportHorizDistance': 3676,
#   'estDepartureAirportVertDistance': 80,
#   'estArrivalAirportHorizDistance': 24061,
#   'estArrivalAirportVertDistance': 1697,
#   'departureAirportCandidatesCount': 2,
#   'arrivalAirportCandidatesCount': 2}]
